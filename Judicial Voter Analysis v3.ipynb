# %% [markdown]
# # Judicial Voter Data Analysis V3

# %% [markdown]
# ### Last updated: 3/6/22

# %% [markdown]
# Notes on data:
# - Only retention races
# - Exclude subcircuit races (shouldn't be any subcircuit races in retention races)
#
# Metrics calcuated:
#
# A. Percentage of people who voted in at least one judicial race: the percentage of votes out of total ballots cast in the judicial race with the highest total votes. This assumes that the total number of votes in the race with the highest votes is equivalent to the number of people who voted in judicial elections. It's possible that someone skipped the highest vote race and voted in another, but we're assuming that's a very small portion of voters, if at all.
#
# (working note: need to see a ranking of top 5 races with the most votes by ward, and see if it's generally the same across wards...or a distribution)
#
# B. Percentage of people who didn't vote in any judicial race: 100% minus A
#
# C. Percentage of judicial voters out of registrered voters.
#
# D. Percentage of regiestered voters who didn't vote in any judicial races.
#
# Google sheets is here: https://docs.google.com/spreadsheets/d/1cR_HXbwe4G9WpkGQxl8u21jGGdNDY_1leo2BQ1P53FQ/edit?usp=sharing

# %%
#Check my working directory
# !pwd
# Out:
# /Users/amy/Code/injustice_watch/analysis

# %%
#Import other packages for analysis
import pandas as pd
from openpyxl import Workbook #used to import .xlsx files
from openpyxl import load_workbook #used to import .xlsx files
import numpy as np

# %% [markdown]
# ### Define Data Cleaning Functions

# %% [markdown]
# Finds and tags retention races

# %%
#Returns the df with an added row called 'Retention'
def tag_retention(df):
    def retention(a):
        if 'No' in a:
            return 'Retention'
        elif 'Yes' in a:
            return 'Retention'
        else:
            return 'Not Retention'
    
    df['Retention'] = df['CANDIDATE'].apply(lambda x: retention(x))
    
    return df

# %%
#Pass a string pathname
#Returns a pandas df
def excel_to_df(pathname): 
    wb = load_workbook(pathname)
    ws = wb.active
    data = ws.values
    columns = next(data)[0:] #Gets the first line in the file as a header line
    df = pd.DataFrame(data, columns=columns)
    
    return df

# %% [markdown]
# ## 2020 General

# %%
#load data into pandas
wb = load_workbook('../Judicial General Data/judicial_general_2020.xlsx')
ws = wb.active
data = ws.values
columns = next(data)[0:] #Gets the first line in the file as a header line
df = pd.DataFrame(data, columns=columns)

# %%
#check the total number of rows = 7,505
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7505 entries, 0 to 7504
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   WARD               7505 non-null   float64
#  1   REGISTERED VOTERS  7505 non-null   float64
#  2   BALLOTS CAST       7505 non-null   float64
#  3   RACE               7505 non-null   object
#  4   CANDIDATE          7505 non-null   object
#  5   VOTES              7505 non-null   float64
# dtypes: float64(4), object(2)
# memory usage: 351.9+ KB

# %%
df.head(20)
# Out:
#     WARD  REGISTERED VOTERS  BALLOTS CAST  \
# 0    1.0            38017.0       30731.0
# 1    1.0            38017.0       30731.0
# 2    1.0            38017.0       30731.0
# 3    1.0            38017.0       30731.0
# 4    1.0            38017.0       30731.0
# 5    1.0            38017.0       30731.0
# 6    1.0            38017.0       30731.0
# 7    1.0            38017.0       30731.0
# 8    1.0            38017.0       30731.0
# 9    1.0            38017.0       30731.0
# 10   1.0            38017.0       30731.0
# 11   1.0            38017.0       30731.0
# 12   1.0            38017.0       30731.0
# 13   1.0            38017.0       30731.0
# 14   1.0            38017.0       30731.0
# 15   1.0            38017.0       30731.0
# 16   1.0            38017.0       30731.0
# 17   1.0            38017.0       30731.0
# 18   1.0            38017.0       30731.0
# 19   1.0            38017.0       30731.0
#
#                                                RACE          CANDIDATE  \
# 0                             Abbey Fishman Romanek                 No
# 1                             Abbey Fishman Romanek                Yes
# 2                                  Andrea M. Buford                 No
# 3                                  Andrea M. Buford                Yes
# 4                                     Anjana Hansen                 No
# 5                                     Anjana Hansen                Yes
# 6                                  Ann Collins-Dole                 No
# 7                                  Ann Collins-Dole                Yes
# 8                           Anna Helen Demacopoulos                 No
# 9                           Anna Helen Demacopoulos                Yes
# 10                Anthony C. ''Tony'' Kyriakopoulos                 No
# 11                Anthony C. ''Tony'' Kyriakopoulos                Yes
# 12  Appellate Court Judge (Vacancy of Neville, Jr.)   Michael B. Hyman
# 13         Appellate Court Judge (Vacancy of Simon)  Sharon O. Johnson
# 14                           Aurelia Marie Pucinski                 No
# 15                           Aurelia Marie Pucinski                Yes
# 16                            Bridget Anne Mitchell                 No
# 17                            Bridget Anne Mitchell                Yes
# 18                                        Broadband                 No
# 19                                        Broadband                Yes
#
#       VOTES
# 0    2839.0
# 1   17794.0
# 2    2683.0
# 3   17950.0
# 4    3801.0
# 5   16603.0
# 6    2789.0
# 7   17806.0
# 8    7004.0
# 9   14045.0
# 10   5029.0
# 11  15572.0
# 12  22042.0
# 13  21676.0
# 14   4793.0
# 15  17770.0
# 16   2636.0
# 17  17656.0
# 18   2499.0
# 19  25981.0

# %%
#clean data
#remove ballot measures 
#total number of rows = 7,187; 318 ballot measures removed
wb = load_workbook('../Judicial General Data/ballot_measures.xlsx')
ws = wb.active
data = ws.values
columns = next(data)[0:] #Gets the first line in the file as a header line
ballot_measures = pd.DataFrame(data, columns=columns)

clean_df = df[~df.RACE.isin(ballot_measures.RACE)]

clean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7187 entries, 0 to 7504
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   WARD               7187 non-null   float64
#  1   REGISTERED VOTERS  7187 non-null   float64
#  2   BALLOTS CAST       7187 non-null   float64
#  3   RACE               7187 non-null   object
#  4   CANDIDATE          7187 non-null   object
#  5   VOTES              7187 non-null   float64
# dtypes: float64(4), object(2)
# memory usage: 393.0+ KB

# %%
clean_df.tail(20)
# Out:
#       WARD  REGISTERED VOTERS  BALLOTS CAST  \
# 7485  50.0            29522.0       21384.0
# 7486  50.0            29522.0       21384.0
# 7487  50.0            29522.0       21384.0
# 7488  50.0            29522.0       21384.0
# 7489  50.0            29522.0       21384.0
# 7490  50.0            29522.0       21384.0
# 7491  50.0            29522.0       21384.0
# 7492  50.0            29522.0       21384.0
# 7493  50.0            29522.0       21384.0
# 7494  50.0            29522.0       21384.0
# 7495  50.0            29522.0       21384.0
# 7496  50.0            29522.0       21384.0
# 7497  50.0            29522.0       21384.0
# 7498  50.0            29522.0       21384.0
# 7499  50.0            29522.0       21384.0
# 7500  50.0            29522.0       21384.0
# 7501  50.0            29522.0       21384.0
# 7502  50.0            29522.0       21384.0
# 7503  50.0            29522.0       21384.0
# 7504  50.0            29522.0       21384.0
#
#                                           RACE              CANDIDATE    VOTES
# 7485                                 Raul Vega                    Yes   9975.0
# 7486                           Robert D. Kuzas                     No   3189.0
# 7487                           Robert D. Kuzas                    Yes   9131.0
# 7488                          Robert E. Gordon                     No   2435.0
# 7489                          Robert E. Gordon                    Yes  10468.0
# 7490                Shelley Lynn Sutker-Dermer                     No   2714.0
# 7491                Shelley Lynn Sutker-Dermer                    Yes  10317.0
# 7492                         Steven G. Watkins                     No   2571.0
# 7493                         Steven G. Watkins                    Yes   9824.0
# 7494  Supreme Court Judge (Vacancy of Freeman)  P. Scott Neville, Jr.  14254.0
# 7495                       Terrence J. McGuire                     No   2490.0
# 7496                       Terrence J. McGuire                    Yes   9796.0
# 7497                           Thomas J. Byrne                     No   3523.0
# 7498                           Thomas J. Byrne                    Yes   9014.0
# 7499                         Thomas J. Carroll                     No   2777.0
# 7500                         Thomas J. Carroll                    Yes   9689.0
# 7501                           Ursula Walowski                     No   2690.0
# 7502                           Ursula Walowski                    Yes   9847.0
# 7503                         William B. Raines                     No   2902.0
# 7504                         William B. Raines                    Yes   9537.0

# %%
#remove non-retention races
#total number of rows = 6,500
clean_df = tag_retention(clean_df)
clean_df = clean_df[clean_df['Retention'] == 'Retention']
clean_df.info()
clean_df.head(20)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6200 entries, 0 to 7504
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   WARD               6200 non-null   float64
#  1   REGISTERED VOTERS  6200 non-null   float64
#  2   BALLOTS CAST       6200 non-null   float64
#  3   RACE               6200 non-null   object
#  4   CANDIDATE          6200 non-null   object
#  5   VOTES              6200 non-null   float64
#  6   Retention          6200 non-null   object
# dtypes: float64(4), object(3)
# memory usage: 387.5+ KB
# <ipython-input-116-62b194e21467>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Retention'] = df['CANDIDATE'].apply(lambda x: retention(x))
#     WARD  REGISTERED VOTERS  BALLOTS CAST                               RACE  \
# 0    1.0            38017.0       30731.0              Abbey Fishman Romanek
# 1    1.0            38017.0       30731.0              Abbey Fishman Romanek
# 2    1.0            38017.0       30731.0                   Andrea M. Buford
# 3    1.0            38017.0       30731.0                   Andrea M. Buford
# 4    1.0            38017.0       30731.0                      Anjana Hansen
# 5    1.0            38017.0       30731.0                      Anjana Hansen
# 6    1.0            38017.0       30731.0                   Ann Collins-Dole
# 7    1.0            38017.0       30731.0                   Ann Collins-Dole
# 8    1.0            38017.0       30731.0            Anna Helen Demacopoulos
# 9    1.0            38017.0       30731.0            Anna Helen Demacopoulos
# 10   1.0            38017.0       30731.0  Anthony C. ''Tony'' Kyriakopoulos
# 11   1.0            38017.0       30731.0  Anthony C. ''Tony'' Kyriakopoulos
# 14   1.0            38017.0       30731.0             Aurelia Marie Pucinski
# 15   1.0            38017.0       30731.0             Aurelia Marie Pucinski
# 16   1.0            38017.0       30731.0              Bridget Anne Mitchell
# 17   1.0            38017.0       30731.0              Bridget Anne Mitchell
# 20   1.0            38017.0       30731.0             Caroline Kate Moreland
# 21   1.0            38017.0       30731.0             Caroline Kate Moreland
# 22   1.0            38017.0       30731.0                     Casandra Lewis
# 23   1.0            38017.0       30731.0                     Casandra Lewis
#
#    CANDIDATE    VOTES  Retention
# 0         No   2839.0  Retention
# 1        Yes  17794.0  Retention
# 2         No   2683.0  Retention
# 3        Yes  17950.0  Retention
# 4         No   3801.0  Retention
# 5        Yes  16603.0  Retention
# 6         No   2789.0  Retention
# 7        Yes  17806.0  Retention
# 8         No   7004.0  Retention
# 9        Yes  14045.0  Retention
# 10        No   5029.0  Retention
# 11       Yes  15572.0  Retention
# 14        No   4793.0  Retention
# 15       Yes  17770.0  Retention
# 16        No   2636.0  Retention
# 17       Yes  17656.0  Retention
# 20        No   5180.0  Retention
# 21       Yes  15421.0  Retention
# 22        No   4655.0  Retention
# 23       Yes  16131.0  Retention

# %%
#export to csv to check in excel
#clean_df.to_csv('Test.csv')

# %%
#group by ward AND race
#make sure registered voters, ballots cast are the same and not summed up
grouped = clean_df.groupby(['WARD','RACE'], as_index=False).agg({'WARD': 'first','REGISTERED VOTERS': 'first',
                                                     'BALLOTS CAST': 'first','VOTES': 'sum'}).sort_values('VOTES',ascending=False)
grouped
# Out:
#                             RACE  WARD  REGISTERED VOTERS  BALLOTS CAST  \
# 2896           Michael P. Toomin  47.0            40767.0       36503.0
# 2893             Mauricio Araujo  47.0            40767.0       36503.0
# 2872  Jackie Marie Portman-Brown  47.0            40767.0       36503.0
# 2858      Aurelia Marie Pucinski  47.0            40767.0       36503.0
# 2882            Kenneth J. Wadas  47.0            40767.0       36503.0
# ...                          ...   ...                ...           ...
# 895              John J. Mahoney  15.0            18597.0       10086.0
# 875        Bridget Anne Mitchell  15.0            18597.0       10086.0
# 921              Robert D. Kuzas  15.0            18597.0       10086.0
# 925          Terrence J. McGuire  15.0            18597.0       10086.0
# 891         James Paul Pieczonka  15.0            18597.0       10086.0
#
#         VOTES
# 2896  28918.0
# 2893  28241.0
# 2872  27914.0
# 2858  27807.0
# 2882  27427.0
# ...       ...
# 895    7087.0
# 875    7086.0
# 921    7070.0
# 925    7054.0
# 891    7038.0
#
# [3100 rows x 5 columns]

# %%
#export to csv to handcheck
grouped.to_csv('grouped.csv')

# %%
#group by race only and show the top 20 races with the most number of votes
#Aurella Marie Pucinski is the race with the most number of votes = 884,434
by_race = clean_df.groupby('RACE').sum().sort_values('VOTES',ascending=False)
by_race.head(20)
# Out:
#                                WARD  REGISTERED VOTERS  BALLOTS CAST     VOTES
# RACE
# Aurelia Marie Pucinski       2550.0          3168586.0     2321986.0  884434.0
# Michael P. Toomin            2550.0          3168586.0     2321986.0  871882.0
# Mauricio Araujo              2550.0          3168586.0     2321986.0  828503.0
# Jackie Marie Portman-Brown   2550.0          3168586.0     2321986.0  825928.0
# James Patrick Flannery, Jr.  2550.0          3168586.0     2321986.0  824548.0
# Mary Ellen Coghlan           2550.0          3168586.0     2321986.0  819483.0
# Kenneth J. Wadas             2550.0          3168586.0     2321986.0  817770.0
# Patricia Manila Martin       2550.0          3168586.0     2321986.0  816891.0
# Mary Katherine Rochford      2550.0          3168586.0     2321986.0  816618.0
# Shelley Lynn Sutker-Dermer   2550.0          3168586.0     2321986.0  814021.0
# Robert E. Gordon             2550.0          3168586.0     2321986.0  813655.0
# Margaret Ann Brennan         2550.0          3168586.0     2321986.0  813458.0
# Kerry M. Kennedy             2550.0          3168586.0     2321986.0  813287.0
# Diana Rosario                2550.0          3168586.0     2321986.0  811823.0
# Gregory J. Wojkowski         2550.0          3168586.0     2321986.0  811407.0
# Raul Vega                    2550.0          3168586.0     2321986.0  809553.0
# Casandra Lewis               2550.0          3168586.0     2321986.0  809453.0
# Laura Marie Sullivan         2550.0          3168586.0     2321986.0  808558.0
# Megan Elizabeth Goldish      2550.0          3168586.0     2321986.0  808420.0
# Lewis Nixon                  2550.0          3168586.0     2321986.0  807335.0

# %% [markdown]
# ## Citywide Participation - 2020 General

# %%
#find total number of ballots cast and registered voters
#first groupby
by_ward = clean_df.groupby('WARD').agg({'REGISTERED VOTERS':'first','BALLOTS CAST':'first'})
by_ward
# Out:
#       REGISTERED VOTERS  BALLOTS CAST
# WARD
# 1.0             38017.0       30731.0
# 2.0             40366.0       34147.0
# 3.0             38027.0       28573.0
# 4.0             34870.0       28567.0
# 5.0             30166.0       24275.0
# 6.0             31173.0       20236.0
# 7.0             31134.0       20337.0
# 8.0             36234.0       24776.0
# 9.0             34876.0       22021.0
# 10.0            26971.0       16218.0
# 11.0            28193.0       20097.0
# 12.0            20782.0       12421.0
# 13.0            29188.0       21131.0
# 14.0            22189.0       14493.0
# 15.0            18597.0       10086.0
# 16.0            23351.0       12802.0
# 17.0            28345.0       17098.0
# 18.0            34053.0       23341.0
# 19.0            38012.0       31598.0
# 20.0            24645.0       15765.0
# 21.0            36601.0       24304.0
# 22.0            20191.0       11881.0
# 23.0            26691.0       18583.0
# 24.0            25688.0       15423.0
# 25.0            29991.0       21741.0
# 26.0            28861.0       20104.0
# 27.0            38160.0       27580.0
# 28.0            31692.0       19441.0
# 29.0            35576.0       23464.0
# 30.0            26664.0       18212.0
# 31.0            25337.0       16414.0
# 32.0            38581.0       33710.0
# 33.0            28354.0       22551.0
# 34.0            35871.0       22582.0
# 35.0            25985.0       18884.0
# 36.0            25569.0       16513.0
# 37.0            29992.0       17614.0
# 38.0            34687.0       25260.0
# 39.0            33720.0       25845.0
# 40.0            33158.0       26726.0
# 41.0            38471.0       30830.0
# 42.0            45319.0       38797.0
# 43.0            36770.0       32679.0
# 44.0            38466.0       34992.0
# 45.0            36353.0       27863.0
# 46.0            35010.0       29917.0
# 47.0            40767.0       36503.0
# 48.0            33825.0       29094.0
# 49.0            29232.0       23389.0
# 50.0            29522.0       21384.0

# %%
#total number of registered voters
by_ward['REGISTERED VOTERS'].sum()
# Out:
# 1584293.0

# %%
#total number of ballots cast
by_ward['BALLOTS CAST'].sum()
# Out:
# 1160993.0

# %%
#overall voter turnout
by_ward['BALLOTS CAST'].sum()/by_ward['REGISTERED VOTERS'].sum()
# Out:
# 0.7328145740718415

# %%
by_race['VOTES'].max()
# Out:
# 884434.0

# %%
#number of votes in the race with the highest votes = 884,434 is Aurelia Marie Pucinski
#calculate participation rate 
participation = 884434/1160993
participation
# Out:
# 0.761790984097234

# %%
#calculate judicial turnout rate
judicial_turnout = 884434/1584293
judicial_turnout
# Out:
# 0.5582515355429836

# %% [markdown]
# ## Citywide Participation 2006-2020

# %%
judicial_list = ['/Users/amy/Code/injustice_watch/Judicial General Data/judicial_general_2006.xlsx',
                '/Users/amy/Code/injustice_watch/Judicial General Data/judicial_general_2008.xlsx',
                '/Users/amy/Code/injustice_watch/Judicial General Data/judicial_general_2010.xlsx',
                '/Users/amy/Code/injustice_watch/Judicial General Data/judicial_general_2012.xlsx',
                '/Users/amy/Code/injustice_watch/Judicial General Data/judicial_general_2014.xlsx',
                '/Users/amy/Code/injustice_watch/Judicial General Data/judicial_general_2016.xlsx',
                '/Users/amy/Code/injustice_watch/Judicial General Data/judicial_general_2018.xlsx',
                '/Users/amy/Code/injustice_watch/Judicial General Data/judicial_general_2020.xlsx']

# %%
participation_list = []
jud_turnout_list = []
turnout_list = []
years_list = ['2006','2008','2010','2012','2014','2016','2018','2020']
ballot_measures_df = excel_to_df('/Users/amy/Code/injustice_watch/Judicial General Data/ballot_measures.xlsx')

index = 0

for pathname in judicial_list:
    print(index)
    df = excel_to_df(pathname)
    df = tag_retention(df)
    clean_df = df[df['Retention'] == 'Retention']
    clean_df = clean_df[~clean_df.RACE.isin(ballot_measures_df.RACE)]
    
    #find race w most votes
    by_race = clean_df.groupby('RACE').sum().sort_values('VOTES',ascending=False)
    print(by_race.head(3))
    max_votes = by_race['VOTES'].max()
    print('max votes')
    print(max_votes)
    
    #find denominators
    by_ward = clean_df.groupby('WARD').agg({'REGISTERED VOTERS':'first','BALLOTS CAST':'first'})
    registered = by_ward['REGISTERED VOTERS'].sum()
    ballots = by_ward['BALLOTS CAST'].sum()
    
    #participation
    participation = max_votes/ballots
    participation_list.append(participation)
    
    #judicial_turnout
    judicial_turnout = max_votes/registered
    jud_turnout_list.append(judicial_turnout)
    
    #voter turnout
    turnout = ballots/registered
    turnout_list.append(turnout)
    
    index+=1
# Out:
# 0
#                      WARD  REGISTERED VOTERS  BALLOTS CAST     VOTES
# RACE
# Patrick J. Quinn   2550.0          2721494.0     1340444.0  436438.0
# Warren D. Wolfson  2550.0          2721494.0     1340444.0  392230.0
# Kathy M. Flanagan  2550.0          2721494.0     1340444.0  389768.0
# max votes
# 436438.0
# 1
#                         WARD  REGISTERED VOTERS  BALLOTS CAST     VOTES
# RACE
# Michael J. Gallagher  2550.0          2994584.0     2211996.0  643592.0
# Thomas E. Flanagan    2550.0          2994584.0     2211996.0  633698.0
# Richard J. Elrod      2550.0          2994584.0     2211996.0  613793.0
# max votes
# 643592.0
# 2
#                         WARD  REGISTERED VOTERS  BALLOTS CAST     VOTES
# RACE
# Charles E. Freeman    2550.0          2669614.0     1411738.0  463055.0
# Thomas R. Fitzgerald  2550.0          2669614.0     1411738.0  451731.0
# Joseph Gordon         2550.0          2669614.0     1411738.0  451562.0
# max votes
# 463055.0
# 3
#                           WARD  REGISTERED VOTERS  BALLOTS CAST     VOTES
# RACE
# James Fitzgerald Smith  2550.0          2728742.0     2057740.0  621185.0
# Carole Kamin Bellows    2550.0          2728742.0     2057740.0  599988.0
# Kathy M. Flanagan       2550.0          2728742.0     2057740.0  597424.0
# max votes
# 621185.0
# 4
#                           WARD  REGISTERED VOTERS  BALLOTS CAST     VOTES
# RACE
# Thomas E. Flanagan      2550.0          2737416.0     1336066.0  436272.0
# Thomas E. Hoffman       2550.0          2737416.0     1336066.0  434289.0
# James Patrick Flannery  2550.0          2737416.0     1336066.0  410070.0
# max votes
# 436272.0
# 5
#                            WARD  REGISTERED VOTERS  BALLOTS CAST     VOTES
# RACE
# Joy Virginia Cunningham  2550.0          3141058.0     2231328.0  699763.0
# Timothy C. Evans         2550.0          3141058.0     2231328.0  692650.0
# Sophia H. Hall           2550.0          3141058.0     2231328.0  689956.0
# max votes
# 699763.0
# 6
#                             WARD  REGISTERED VOTERS  BALLOTS CAST     VOTES
# RACE
# Anne M. Burke             2550.0          3006706.0     1824122.0  674981.0
# Margaret Stanton McBride  2550.0          3006706.0     1824122.0  649419.0
# Kathy M. Flanagan         2550.0          3006706.0     1824122.0  647006.0
# max votes
# 674981.0
# 7
#                           WARD  REGISTERED VOTERS  BALLOTS CAST     VOTES
# RACE
# Aurelia Marie Pucinski  2550.0          3168586.0     2321986.0  884434.0
# Michael P. Toomin       2550.0          3168586.0     2321986.0  871882.0
# Mauricio Araujo         2550.0          3168586.0     2321986.0  828503.0
# max votes
# 884434.0

# %%
#check 2020
participation_list
# Out:
# [0.6511842344775314,
#  0.581910636366431,
#  0.6560069927989471,
#  0.6037546045661746,
#  0.6530695339900873,
#  0.6272166171894047,
#  0.7400612459035086,
#  0.761790984097234]

# %%
jud_turnout_list
# Out:
# [0.3207341261821632,
#  0.4298373329985066,
#  0.34690783012075904,
#  0.45529038655908105,
#  0.3187473149861037,
#  0.445558789427002,
#  0.44898370509121943,
#  0.5582515355429836]

# %%
turnout_list
# Out:
# [0.49253975941155853,
#  0.7386655375170641,
#  0.5288172747071299,
#  0.7540984087172771,
#  0.4880756158362485,
#  0.7103746572014907,
#  0.6066845245261758,
#  0.7328145740718415]

# %%
#save into a dictionary and convert to df
dict_to_df = {
    'Year':years_list,
    'Participation':participation_list,
    'Judicial Turnout':jud_turnout_list,
    'Voter Turnout':turnout_list,
}

summary_df = pd.DataFrame(dict_to_df)
summary_df
# Out:
#    Year  Participation  Judicial Turnout  Voter Turnout
# 0  2006       0.651184          0.320734       0.492540
# 1  2008       0.581911          0.429837       0.738666
# 2  2010       0.656007          0.346908       0.528817
# 3  2012       0.603755          0.455290       0.754098
# 4  2014       0.653070          0.318747       0.488076
# 5  2016       0.627217          0.445559       0.710375
# 6  2018       0.740061          0.448984       0.606685
# 7  2020       0.761791          0.558252       0.732815

# %% [markdown]
# ## Ward by Ward Participation TK

# %% [markdown]
# Is the race with the highest votes based on the entire city or by ward? Having trouble figuring out how to calculate that in pandas

# %%
#calculate voter turnout by ward 
by_ward['TURNOUT'] = by_ward['BALLOTS CAST']/by_ward['REGISTERED VOTERS']
by_ward
# Out:
#       REGISTERED VOTERS  BALLOTS CAST   TURNOUT
# WARD
# 1.0             38017.0       30731.0  0.808349
# 2.0             40366.0       34147.0  0.845935
# 3.0             38027.0       28573.0  0.751387
# 4.0             34870.0       28567.0  0.819243
# 5.0             30166.0       24275.0  0.804714
# 6.0             31173.0       20236.0  0.649152
# 7.0             31134.0       20337.0  0.653209
# 8.0             36234.0       24776.0  0.683778
# 9.0             34876.0       22021.0  0.631408
# 10.0            26971.0       16218.0  0.601313
# 11.0            28193.0       20097.0  0.712837
# 12.0            20782.0       12421.0  0.597681
# 13.0            29188.0       21131.0  0.723962
# 14.0            22189.0       14493.0  0.653161
# 15.0            18597.0       10086.0  0.542346
# 16.0            23351.0       12802.0  0.548242
# 17.0            28345.0       17098.0  0.603210
# 18.0            34053.0       23341.0  0.685432
# 19.0            38012.0       31598.0  0.831264
# 20.0            24645.0       15765.0  0.639684
# 21.0            36601.0       24304.0  0.664026
# 22.0            20191.0       11881.0  0.588430
# 23.0            26691.0       18583.0  0.696227
# 24.0            25688.0       15423.0  0.600397
# 25.0            29991.0       21741.0  0.724917
# 26.0            28861.0       20104.0  0.696580
# 27.0            38160.0       27580.0  0.722746
# 28.0            31692.0       19441.0  0.613436
# 29.0            35576.0       23464.0  0.659546
# 30.0            26664.0       18212.0  0.683018
# 31.0            25337.0       16414.0  0.647827
# 32.0            38581.0       33710.0  0.873746
# 33.0            28354.0       22551.0  0.795338
# 34.0            35871.0       22582.0  0.629534
# 35.0            25985.0       18884.0  0.726727
# 36.0            25569.0       16513.0  0.645821
# 37.0            29992.0       17614.0  0.587290
# 38.0            34687.0       25260.0  0.728227
# 39.0            33720.0       25845.0  0.766459
# 40.0            33158.0       26726.0  0.806020
# 41.0            38471.0       30830.0  0.801383
# 42.0            45319.0       38797.0  0.856087
# 43.0            36770.0       32679.0  0.888741
# 44.0            38466.0       34992.0  0.909686
# 45.0            36353.0       27863.0  0.766457
# 46.0            35010.0       29917.0  0.854527
# 47.0            40767.0       36503.0  0.895406
# 48.0            33825.0       29094.0  0.860133
# 49.0            29232.0       23389.0  0.800116
# 50.0            29522.0       21384.0  0.724341
