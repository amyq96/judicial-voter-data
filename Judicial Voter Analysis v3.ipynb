# %% [markdown]
# # Judicial Voter Data Analysis V3

# %% [markdown]
# ### Last updated: 5/8/22

# %% [markdown]
# Notes on data:
# - Only retention races
# - Exclude subcircuit races (shouldn't be any subcircuit races in retention races)
#
# Metrics calcuated:
#
# A. Percentage of people who voted in at least one judicial race: the percentage of votes out of total ballots cast in the judicial race with the highest total votes. This assumes that the total number of votes in the race with the highest votes is equivalent to the number of people who voted in judicial elections. It's possible that someone skipped the highest vote race and voted in another, but we're assuming that's a very small portion of voters, if at all.
#
# (working note: need to see a ranking of top 5 races with the most votes by ward, and see if it's generally the same across wards...or a distribution)
#
# B. Percentage of people who didn't vote in any judicial race: 100% minus A
#
# C. Percentage of judicial voters out of registrered voters.
#
# D. Percentage of regiestered voters who didn't vote in any judicial races.
#
# Google sheets is here: https://docs.google.com/spreadsheets/d/1cR_HXbwe4G9WpkGQxl8u21jGGdNDY_1leo2BQ1P53FQ/edit?usp=sharing

# %%
#Check my working directory
# !pwd
# Out:
# /Users/amy/Code/injustice_watch/analysis

# %%
#Import other packages for analysis
import pandas as pd
from openpyxl import Workbook #used to import .xlsx files
from openpyxl import load_workbook #used to import .xlsx files
import numpy as np
#import gspread

# %% [markdown]
# ### Define Data Cleaning Functions

# %% [markdown]
# Finds and tags retention races

# %%
#Returns the df with an added row called 'Retention'
def tag_retention(df):
    def retention(a):
        if 'No' in a:
            return 'Retention'
        elif 'Yes' in a:
            return 'Retention'
        else:
            return 'Not Retention'
    
    df['Retention'] = df['CANDIDATE'].apply(lambda x: retention(x))
    
    return df

# %%
#finds and tags subcircuits
def tag_subcircuit(df):
    def subcircuit(a):
        if 'Subcircuit' in a:
            return 'Subcircuit'
        elif 'Sub' in a: #accounts for 2006 notation
            return 'Subcircuit'
        else:
            return 'Not Subcircuit'
   
    df['Subcircuit'] = df['RACE'].apply(lambda x: subcircuit(x))
    
    return df

# %%
#Pass a string pathname
#Returns a pandas df
def excel_to_df(pathname): 
    wb = load_workbook(pathname)
    ws = wb.active
    data = ws.values
    columns = next(data)[0:] #Gets the first line in the file as a header line
    df = pd.DataFrame(data, columns=columns)
    
    return df

# %% [markdown]
# ## 2020 General - Citywide

# %%
#load data into pandas
wb = load_workbook('../Judicial General Data/judicial_general_2020.xlsx')
ws = wb.active
data = ws.values
columns = next(data)[0:] #Gets the first line in the file as a header line
df = pd.DataFrame(data, columns=columns)

# %%
#check the total number of rows = 7,505
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7505 entries, 0 to 7504
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   WARD               7505 non-null   float64
#  1   REGISTERED VOTERS  7505 non-null   float64
#  2   BALLOTS CAST       7505 non-null   float64
#  3   RACE               7505 non-null   object
#  4   CANDIDATE          7505 non-null   object
#  5   VOTES              7505 non-null   float64
# dtypes: float64(4), object(2)
# memory usage: 351.9+ KB

# %%
df.head(20)
# Out:
#     WARD  REGISTERED VOTERS  BALLOTS CAST  \
# 0    1.0            38017.0       30731.0
# 1    1.0            38017.0       30731.0
# 2    1.0            38017.0       30731.0
# 3    1.0            38017.0       30731.0
# 4    1.0            38017.0       30731.0
# 5    1.0            38017.0       30731.0
# 6    1.0            38017.0       30731.0
# 7    1.0            38017.0       30731.0
# 8    1.0            38017.0       30731.0
# 9    1.0            38017.0       30731.0
# 10   1.0            38017.0       30731.0
# 11   1.0            38017.0       30731.0
# 12   1.0            38017.0       30731.0
# 13   1.0            38017.0       30731.0
# 14   1.0            38017.0       30731.0
# 15   1.0            38017.0       30731.0
# 16   1.0            38017.0       30731.0
# 17   1.0            38017.0       30731.0
# 18   1.0            38017.0       30731.0
# 19   1.0            38017.0       30731.0
#
#                                                RACE          CANDIDATE  \
# 0                             Abbey Fishman Romanek                 No
# 1                             Abbey Fishman Romanek                Yes
# 2                                  Andrea M. Buford                 No
# 3                                  Andrea M. Buford                Yes
# 4                                     Anjana Hansen                 No
# 5                                     Anjana Hansen                Yes
# 6                                  Ann Collins-Dole                 No
# 7                                  Ann Collins-Dole                Yes
# 8                           Anna Helen Demacopoulos                 No
# 9                           Anna Helen Demacopoulos                Yes
# 10                Anthony C. ''Tony'' Kyriakopoulos                 No
# 11                Anthony C. ''Tony'' Kyriakopoulos                Yes
# 12  Appellate Court Judge (Vacancy of Neville, Jr.)   Michael B. Hyman
# 13         Appellate Court Judge (Vacancy of Simon)  Sharon O. Johnson
# 14                           Aurelia Marie Pucinski                 No
# 15                           Aurelia Marie Pucinski                Yes
# 16                            Bridget Anne Mitchell                 No
# 17                            Bridget Anne Mitchell                Yes
# 18                                        Broadband                 No
# 19                                        Broadband                Yes
#
#       VOTES
# 0    2839.0
# 1   17794.0
# 2    2683.0
# 3   17950.0
# 4    3801.0
# 5   16603.0
# 6    2789.0
# 7   17806.0
# 8    7004.0
# 9   14045.0
# 10   5029.0
# 11  15572.0
# 12  22042.0
# 13  21676.0
# 14   4793.0
# 15  17770.0
# 16   2636.0
# 17  17656.0
# 18   2499.0
# 19  25981.0

# %%
#clean data
#remove ballot measures 
#total number of rows = 7,187; 318 ballot measures removed
wb = load_workbook('../Judicial General Data/ballot_measures.xlsx')
ws = wb.active
data = ws.values
columns = next(data)[0:] #Gets the first line in the file as a header line
ballot_measures = pd.DataFrame(data, columns=columns)

clean_df = df[~df.RACE.isin(ballot_measures.RACE)]

clean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7187 entries, 0 to 7504
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   WARD               7187 non-null   float64
#  1   REGISTERED VOTERS  7187 non-null   float64
#  2   BALLOTS CAST       7187 non-null   float64
#  3   RACE               7187 non-null   object
#  4   CANDIDATE          7187 non-null   object
#  5   VOTES              7187 non-null   float64
# dtypes: float64(4), object(2)
# memory usage: 393.0+ KB

# %%
clean_df.tail(20)
# Out:
#       WARD  REGISTERED VOTERS  BALLOTS CAST  \
# 7485  50.0            29522.0       21384.0
# 7486  50.0            29522.0       21384.0
# 7487  50.0            29522.0       21384.0
# 7488  50.0            29522.0       21384.0
# 7489  50.0            29522.0       21384.0
# 7490  50.0            29522.0       21384.0
# 7491  50.0            29522.0       21384.0
# 7492  50.0            29522.0       21384.0
# 7493  50.0            29522.0       21384.0
# 7494  50.0            29522.0       21384.0
# 7495  50.0            29522.0       21384.0
# 7496  50.0            29522.0       21384.0
# 7497  50.0            29522.0       21384.0
# 7498  50.0            29522.0       21384.0
# 7499  50.0            29522.0       21384.0
# 7500  50.0            29522.0       21384.0
# 7501  50.0            29522.0       21384.0
# 7502  50.0            29522.0       21384.0
# 7503  50.0            29522.0       21384.0
# 7504  50.0            29522.0       21384.0
#
#                                           RACE              CANDIDATE    VOTES
# 7485                                 Raul Vega                    Yes   9975.0
# 7486                           Robert D. Kuzas                     No   3189.0
# 7487                           Robert D. Kuzas                    Yes   9131.0
# 7488                          Robert E. Gordon                     No   2435.0
# 7489                          Robert E. Gordon                    Yes  10468.0
# 7490                Shelley Lynn Sutker-Dermer                     No   2714.0
# 7491                Shelley Lynn Sutker-Dermer                    Yes  10317.0
# 7492                         Steven G. Watkins                     No   2571.0
# 7493                         Steven G. Watkins                    Yes   9824.0
# 7494  Supreme Court Judge (Vacancy of Freeman)  P. Scott Neville, Jr.  14254.0
# 7495                       Terrence J. McGuire                     No   2490.0
# 7496                       Terrence J. McGuire                    Yes   9796.0
# 7497                           Thomas J. Byrne                     No   3523.0
# 7498                           Thomas J. Byrne                    Yes   9014.0
# 7499                         Thomas J. Carroll                     No   2777.0
# 7500                         Thomas J. Carroll                    Yes   9689.0
# 7501                           Ursula Walowski                     No   2690.0
# 7502                           Ursula Walowski                    Yes   9847.0
# 7503                         William B. Raines                     No   2902.0
# 7504                         William B. Raines                    Yes   9537.0

# %%
#remove non-retention races
#total number of rows = 6,200
clean_df = tag_retention(clean_df)
clean_df = clean_df[clean_df['Retention'] == 'Retention']
clean_df.info()
clean_df.head(20)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6200 entries, 0 to 7504
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   WARD               6200 non-null   float64
#  1   REGISTERED VOTERS  6200 non-null   float64
#  2   BALLOTS CAST       6200 non-null   float64
#  3   RACE               6200 non-null   object
#  4   CANDIDATE          6200 non-null   object
#  5   VOTES              6200 non-null   float64
#  6   Retention          6200 non-null   object
# dtypes: float64(4), object(3)
# memory usage: 387.5+ KB
# <ipython-input-72-62b194e21467>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Retention'] = df['CANDIDATE'].apply(lambda x: retention(x))
#     WARD  REGISTERED VOTERS  BALLOTS CAST                               RACE  \
# 0    1.0            38017.0       30731.0              Abbey Fishman Romanek
# 1    1.0            38017.0       30731.0              Abbey Fishman Romanek
# 2    1.0            38017.0       30731.0                   Andrea M. Buford
# 3    1.0            38017.0       30731.0                   Andrea M. Buford
# 4    1.0            38017.0       30731.0                      Anjana Hansen
# 5    1.0            38017.0       30731.0                      Anjana Hansen
# 6    1.0            38017.0       30731.0                   Ann Collins-Dole
# 7    1.0            38017.0       30731.0                   Ann Collins-Dole
# 8    1.0            38017.0       30731.0            Anna Helen Demacopoulos
# 9    1.0            38017.0       30731.0            Anna Helen Demacopoulos
# 10   1.0            38017.0       30731.0  Anthony C. ''Tony'' Kyriakopoulos
# 11   1.0            38017.0       30731.0  Anthony C. ''Tony'' Kyriakopoulos
# 14   1.0            38017.0       30731.0             Aurelia Marie Pucinski
# 15   1.0            38017.0       30731.0             Aurelia Marie Pucinski
# 16   1.0            38017.0       30731.0              Bridget Anne Mitchell
# 17   1.0            38017.0       30731.0              Bridget Anne Mitchell
# 20   1.0            38017.0       30731.0             Caroline Kate Moreland
# 21   1.0            38017.0       30731.0             Caroline Kate Moreland
# 22   1.0            38017.0       30731.0                     Casandra Lewis
# 23   1.0            38017.0       30731.0                     Casandra Lewis
#
#    CANDIDATE    VOTES  Retention
# 0         No   2839.0  Retention
# 1        Yes  17794.0  Retention
# 2         No   2683.0  Retention
# 3        Yes  17950.0  Retention
# 4         No   3801.0  Retention
# 5        Yes  16603.0  Retention
# 6         No   2789.0  Retention
# 7        Yes  17806.0  Retention
# 8         No   7004.0  Retention
# 9        Yes  14045.0  Retention
# 10        No   5029.0  Retention
# 11       Yes  15572.0  Retention
# 14        No   4793.0  Retention
# 15       Yes  17770.0  Retention
# 16        No   2636.0  Retention
# 17       Yes  17656.0  Retention
# 20        No   5180.0  Retention
# 21       Yes  15421.0  Retention
# 22        No   4655.0  Retention
# 23       Yes  16131.0  Retention

# %%
#export to csv to check in excel
clean_df.to_csv('Test.csv')

# %%
#group by ward AND race
#should be 3,100 or half of the number of rows in clean_df
#make sure registered voters, ballots cast are the same and not summed up
grouped = clean_df.groupby(['WARD','RACE'], as_index=False).agg({'WARD': 'first','REGISTERED VOTERS': 'first',
                                                     'BALLOTS CAST': 'first','VOTES': 'sum'}).sort_values('VOTES',ascending=False)
grouped
# Out:
#                             RACE  WARD  REGISTERED VOTERS  BALLOTS CAST  \
# 2896           Michael P. Toomin  47.0            40767.0       36503.0
# 2893             Mauricio Araujo  47.0            40767.0       36503.0
# 2872  Jackie Marie Portman-Brown  47.0            40767.0       36503.0
# 2858      Aurelia Marie Pucinski  47.0            40767.0       36503.0
# 2882            Kenneth J. Wadas  47.0            40767.0       36503.0
# ...                          ...   ...                ...           ...
# 895              John J. Mahoney  15.0            18597.0       10086.0
# 875        Bridget Anne Mitchell  15.0            18597.0       10086.0
# 921              Robert D. Kuzas  15.0            18597.0       10086.0
# 925          Terrence J. McGuire  15.0            18597.0       10086.0
# 891         James Paul Pieczonka  15.0            18597.0       10086.0
#
#         VOTES
# 2896  28918.0
# 2893  28241.0
# 2872  27914.0
# 2858  27807.0
# 2882  27427.0
# ...       ...
# 895    7087.0
# 875    7086.0
# 921    7070.0
# 925    7054.0
# 891    7038.0
#
# [3100 rows x 5 columns]

# %%
#export to csv to handcheck
grouped.to_csv('grouped.csv')

# %%
#group by race only and show the top 20 races with the most number of votes
#Aurella Marie Pucinski is the race with the most number of votes = 884,434
by_race = clean_df.groupby('RACE').sum().sort_values('VOTES',ascending=False)
by_race.head(20)
# Out:
#                                WARD  REGISTERED VOTERS  BALLOTS CAST     VOTES
# RACE
# Aurelia Marie Pucinski       2550.0          3168586.0     2321986.0  884434.0
# Michael P. Toomin            2550.0          3168586.0     2321986.0  871882.0
# Mauricio Araujo              2550.0          3168586.0     2321986.0  828503.0
# Jackie Marie Portman-Brown   2550.0          3168586.0     2321986.0  825928.0
# James Patrick Flannery, Jr.  2550.0          3168586.0     2321986.0  824548.0
# Mary Ellen Coghlan           2550.0          3168586.0     2321986.0  819483.0
# Kenneth J. Wadas             2550.0          3168586.0     2321986.0  817770.0
# Patricia Manila Martin       2550.0          3168586.0     2321986.0  816891.0
# Mary Katherine Rochford      2550.0          3168586.0     2321986.0  816618.0
# Shelley Lynn Sutker-Dermer   2550.0          3168586.0     2321986.0  814021.0
# Robert E. Gordon             2550.0          3168586.0     2321986.0  813655.0
# Margaret Ann Brennan         2550.0          3168586.0     2321986.0  813458.0
# Kerry M. Kennedy             2550.0          3168586.0     2321986.0  813287.0
# Diana Rosario                2550.0          3168586.0     2321986.0  811823.0
# Gregory J. Wojkowski         2550.0          3168586.0     2321986.0  811407.0
# Raul Vega                    2550.0          3168586.0     2321986.0  809553.0
# Casandra Lewis               2550.0          3168586.0     2321986.0  809453.0
# Laura Marie Sullivan         2550.0          3168586.0     2321986.0  808558.0
# Megan Elizabeth Goldish      2550.0          3168586.0     2321986.0  808420.0
# Lewis Nixon                  2550.0          3168586.0     2321986.0  807335.0

# %% [markdown]
# ## Citywide Participation - 2020 General

# %%
#find total number of ballots cast and registered voters
#first groupby
by_ward = clean_df.groupby('WARD').agg({'REGISTERED VOTERS':'first','BALLOTS CAST':'first'})
by_ward
# Out:
#       REGISTERED VOTERS  BALLOTS CAST
# WARD
# 1.0             38017.0       30731.0
# 2.0             40366.0       34147.0
# 3.0             38027.0       28573.0
# 4.0             34870.0       28567.0
# 5.0             30166.0       24275.0
# 6.0             31173.0       20236.0
# 7.0             31134.0       20337.0
# 8.0             36234.0       24776.0
# 9.0             34876.0       22021.0
# 10.0            26971.0       16218.0
# 11.0            28193.0       20097.0
# 12.0            20782.0       12421.0
# 13.0            29188.0       21131.0
# 14.0            22189.0       14493.0
# 15.0            18597.0       10086.0
# 16.0            23351.0       12802.0
# 17.0            28345.0       17098.0
# 18.0            34053.0       23341.0
# 19.0            38012.0       31598.0
# 20.0            24645.0       15765.0
# 21.0            36601.0       24304.0
# 22.0            20191.0       11881.0
# 23.0            26691.0       18583.0
# 24.0            25688.0       15423.0
# 25.0            29991.0       21741.0
# 26.0            28861.0       20104.0
# 27.0            38160.0       27580.0
# 28.0            31692.0       19441.0
# 29.0            35576.0       23464.0
# 30.0            26664.0       18212.0
# 31.0            25337.0       16414.0
# 32.0            38581.0       33710.0
# 33.0            28354.0       22551.0
# 34.0            35871.0       22582.0
# 35.0            25985.0       18884.0
# 36.0            25569.0       16513.0
# 37.0            29992.0       17614.0
# 38.0            34687.0       25260.0
# 39.0            33720.0       25845.0
# 40.0            33158.0       26726.0
# 41.0            38471.0       30830.0
# 42.0            45319.0       38797.0
# 43.0            36770.0       32679.0
# 44.0            38466.0       34992.0
# 45.0            36353.0       27863.0
# 46.0            35010.0       29917.0
# 47.0            40767.0       36503.0
# 48.0            33825.0       29094.0
# 49.0            29232.0       23389.0
# 50.0            29522.0       21384.0

# %%
#total number of registered voters
by_ward['REGISTERED VOTERS'].sum()
# Out:
# 1584293.0

# %%
#total number of ballots cast
by_ward['BALLOTS CAST'].sum()
# Out:
# 1160993.0

# %%
#overall voter turnout
by_ward['BALLOTS CAST'].sum()/by_ward['REGISTERED VOTERS'].sum()
# Out:
# 0.7328145740718415

# %%
by_race['VOTES'].max()
# Out:
# 884434.0

# %%
#number of votes in the race with the highest votes = 884,434 is Aurelia Marie Pucinski
#calculate participation rate 
participation = 884434/1160993
participation
# Out:
# 0.761790984097234

# %%
#calculate judicial turnout rate
judicial_turnout = 884434/1584293
judicial_turnout
# Out:
# 0.5582515355429836

# %% [markdown]
# ## Citywide Participation 2006-2020

# %%
judicial_list = ['/Users/amy/Code/injustice_watch/Judicial General Data/judicial_general_2006.xlsx',
                '/Users/amy/Code/injustice_watch/Judicial General Data/judicial_general_2008.xlsx',
                '/Users/amy/Code/injustice_watch/Judicial General Data/judicial_general_2010.xlsx',
                '/Users/amy/Code/injustice_watch/Judicial General Data/judicial_general_2012.xlsx',
                '/Users/amy/Code/injustice_watch/Judicial General Data/judicial_general_2014.xlsx',
                '/Users/amy/Code/injustice_watch/Judicial General Data/judicial_general_2016.xlsx',
                '/Users/amy/Code/injustice_watch/Judicial General Data/judicial_general_2018.xlsx',
                '/Users/amy/Code/injustice_watch/Judicial General Data/judicial_general_2020.xlsx']

# %%
participation_list = []
jud_turnout_list = []
turnout_list = []
years_list = ['2006','2008','2010','2012','2014','2016','2018','2020']
ballot_measures_df = excel_to_df('/Users/amy/Code/injustice_watch/Judicial General Data/ballot_measures.xlsx')

index = 0

for pathname in judicial_list:
    print(index)
    df = excel_to_df(pathname)
    df = tag_retention(df)
    clean_df = df[df['Retention'] == 'Retention']
    clean_df = clean_df[~clean_df.RACE.isin(ballot_measures_df.RACE)]
    
    #find race w most votes
    by_race = clean_df.groupby('RACE').sum().sort_values('VOTES',ascending=False)
    print(by_race.head(3))
    max_votes = by_race['VOTES'].max()
    print('max votes')
    print(max_votes)
    
    #find denominators
    by_ward = clean_df.groupby('WARD').agg({'REGISTERED VOTERS':'first','BALLOTS CAST':'first'})
    registered = by_ward['REGISTERED VOTERS'].sum()
    ballots = by_ward['BALLOTS CAST'].sum()
    
    #participation
    participation = max_votes/ballots
    participation_list.append(participation)
    
    #judicial_turnout
    judicial_turnout = max_votes/registered
    jud_turnout_list.append(judicial_turnout)
    
    #voter turnout
    turnout = ballots/registered
    turnout_list.append(turnout)
    
    index+=1
# Out:
# 0
#                      WARD  REGISTERED VOTERS  BALLOTS CAST     VOTES
# RACE
# Patrick J. Quinn   2550.0          2721494.0     1340444.0  436438.0
# Warren D. Wolfson  2550.0          2721494.0     1340444.0  392230.0
# Kathy M. Flanagan  2550.0          2721494.0     1340444.0  389768.0
# max votes
# 436438.0
# 1
#                         WARD  REGISTERED VOTERS  BALLOTS CAST     VOTES
# RACE
# Michael J. Gallagher  2550.0          2994584.0     2211996.0  643592.0
# Thomas E. Flanagan    2550.0          2994584.0     2211996.0  633698.0
# Richard J. Elrod      2550.0          2994584.0     2211996.0  613793.0
# max votes
# 643592.0
# 2
#                         WARD  REGISTERED VOTERS  BALLOTS CAST     VOTES
# RACE
# Charles E. Freeman    2550.0          2669614.0     1411738.0  463055.0
# Thomas R. Fitzgerald  2550.0          2669614.0     1411738.0  451731.0
# Joseph Gordon         2550.0          2669614.0     1411738.0  451562.0
# max votes
# 463055.0
# 3
#                           WARD  REGISTERED VOTERS  BALLOTS CAST     VOTES
# RACE
# James Fitzgerald Smith  2550.0          2728742.0     2057740.0  621185.0
# Carole Kamin Bellows    2550.0          2728742.0     2057740.0  599988.0
# Kathy M. Flanagan       2550.0          2728742.0     2057740.0  597424.0
# max votes
# 621185.0
# 4
#                           WARD  REGISTERED VOTERS  BALLOTS CAST     VOTES
# RACE
# Thomas E. Flanagan      2550.0          2737416.0     1336066.0  436272.0
# Thomas E. Hoffman       2550.0          2737416.0     1336066.0  434289.0
# James Patrick Flannery  2550.0          2737416.0     1336066.0  410070.0
# max votes
# 436272.0
# 5
#                            WARD  REGISTERED VOTERS  BALLOTS CAST     VOTES
# RACE
# Joy Virginia Cunningham  2550.0          3141058.0     2231328.0  699763.0
# Timothy C. Evans         2550.0          3141058.0     2231328.0  692650.0
# Sophia H. Hall           2550.0          3141058.0     2231328.0  689956.0
# max votes
# 699763.0
# 6
#                             WARD  REGISTERED VOTERS  BALLOTS CAST     VOTES
# RACE
# Anne M. Burke             2550.0          3006706.0     1824122.0  674981.0
# Margaret Stanton McBride  2550.0          3006706.0     1824122.0  649419.0
# Kathy M. Flanagan         2550.0          3006706.0     1824122.0  647006.0
# max votes
# 674981.0
# 7
#                           WARD  REGISTERED VOTERS  BALLOTS CAST     VOTES
# RACE
# Aurelia Marie Pucinski  2550.0          3168586.0     2321986.0  884434.0
# Michael P. Toomin       2550.0          3168586.0     2321986.0  871882.0
# Mauricio Araujo         2550.0          3168586.0     2321986.0  828503.0
# max votes
# 884434.0

# %%
#check 2020
participation_list
# Out:
# [0.6511842344775314,
#  0.581910636366431,
#  0.6560069927989471,
#  0.6037546045661746,
#  0.6530695339900873,
#  0.6272166171894047,
#  0.7400612459035086,
#  0.761790984097234]

# %%
jud_turnout_list
# Out:
# [0.3207341261821632,
#  0.4298373329985066,
#  0.34690783012075904,
#  0.45529038655908105,
#  0.3187473149861037,
#  0.445558789427002,
#  0.44898370509121943,
#  0.5582515355429836]

# %%
turnout_list
# Out:
# [0.49253975941155853,
#  0.7386655375170641,
#  0.5288172747071299,
#  0.7540984087172771,
#  0.4880756158362485,
#  0.7103746572014907,
#  0.6066845245261758,
#  0.7328145740718415]

# %%
#save into a dictionary and convert to df
dict_to_df = {
    'Year':years_list,
    'Participation':participation_list,
    'Judicial Turnout':jud_turnout_list,
    'Voter Turnout':turnout_list,
}

summary_df = pd.DataFrame(dict_to_df)
summary_df
# Out:
#    Year  Participation  Judicial Turnout  Voter Turnout
# 0  2006       0.651184          0.320734       0.492540
# 1  2008       0.581911          0.429837       0.738666
# 2  2010       0.656007          0.346908       0.528817
# 3  2012       0.603755          0.455290       0.754098
# 4  2014       0.653070          0.318747       0.488076
# 5  2016       0.627217          0.445559       0.710375
# 6  2018       0.740061          0.448984       0.606685
# 7  2020       0.761791          0.558252       0.732815

# %% [markdown]
# ## Ward by Ward Participation 2020

# %% [markdown]
# To calculate ward by ward particpation, need to find the race with the highest particpation for each ward (which varies from ward to ward) because that's what would actually measure the percentage of people in that ward who likely participated in a judicial race.
#
# Tutorials used
#
# To find max of each ward w/ transform.max: https://stackoverflow.com/questions/43524549/pandas-groupby-transform-max-with-filter

# %%
#will need to start with the grouped by race dataframe
grouped.head(10)
# Out:
#                             RACE  WARD  REGISTERED VOTERS  BALLOTS CAST  \
# 2896           Michael P. Toomin  47.0            40767.0       36503.0
# 2893             Mauricio Araujo  47.0            40767.0       36503.0
# 2872  Jackie Marie Portman-Brown  47.0            40767.0       36503.0
# 2858      Aurelia Marie Pucinski  47.0            40767.0       36503.0
# 2882            Kenneth J. Wadas  47.0            40767.0       36503.0
# 2856     Anna Helen Demacopoulos  47.0            40767.0       36503.0
# 2867               Diana Rosario  47.0            40767.0       36503.0
# 2879             John J. Mahoney  47.0            40767.0       36503.0
# 2891     Mary Katherine Rochford  47.0            40767.0       36503.0
# 2899      Patricia Manila Martin  47.0            40767.0       36503.0
#
#         VOTES
# 2896  28918.0
# 2893  28241.0
# 2872  27914.0
# 2858  27807.0
# 2882  27427.0
# 2856  27106.0
# 2867  27031.0
# 2879  27003.0
# 2891  26979.0
# 2899  26923.0

# %%
#find max votes in each ward
grouped['max_votes'] = grouped.groupby(['WARD'])['VOTES'].transform(max)
grouped.head()
# Out:
#                             RACE  WARD  REGISTERED VOTERS  BALLOTS CAST  \
# 2896           Michael P. Toomin  47.0            40767.0       36503.0
# 2893             Mauricio Araujo  47.0            40767.0       36503.0
# 2872  Jackie Marie Portman-Brown  47.0            40767.0       36503.0
# 2858      Aurelia Marie Pucinski  47.0            40767.0       36503.0
# 2882            Kenneth J. Wadas  47.0            40767.0       36503.0
#
#         VOTES  max_votes
# 2896  28918.0    28918.0
# 2893  28241.0    28918.0
# 2872  27914.0    28918.0
# 2858  27807.0    28918.0
# 2882  27427.0    28918.0

# %%
#See if max_votes is the same in a ward
grouped.loc[test['WARD'] == 48.0]
# Out:
#                             RACE  WARD  REGISTERED VOTERS  BALLOTS CAST  \
# 2958           Michael P. Toomin  48.0            33825.0       29094.0
# 2920      Aurelia Marie Pucinski  48.0            33825.0       29094.0
# 2955             Mauricio Araujo  48.0            33825.0       29094.0
# 2934  Jackie Marie Portman-Brown  48.0            33825.0       29094.0
# 2944            Kenneth J. Wadas  48.0            33825.0       29094.0
# ...                          ...   ...                ...           ...
# 2932              Edward A. Arce  48.0            33825.0       29094.0
# 2967             Robert D. Kuzas  48.0            33825.0       29094.0
# 2921       Bridget Anne Mitchell  48.0            33825.0       29094.0
# 2937        James Paul Pieczonka  48.0            33825.0       29094.0
# 2971         Terrence J. McGuire  48.0            33825.0       29094.0
#
#         VOTES  max_votes
# 2958  22296.0    22296.0
# 2920  21992.0    22296.0
# 2955  21560.0    22296.0
# 2934  21388.0    22296.0
# 2944  21059.0    22296.0
# ...       ...        ...
# 2932  20195.0    22296.0
# 2967  20115.0    22296.0
# 2921  20088.0    22296.0
# 2937  20079.0    22296.0
# 2971  19988.0    22296.0
#
# [62 rows x 6 columns]

# %%
#consolidate by ward
data_by_ward = grouped.groupby(['WARD'], as_index=False).agg({'WARD': 'first','REGISTERED VOTERS': 'first',
                                                     'BALLOTS CAST': 'first','max_votes':'first'})

# 30          0.511900  0.647827
# 31          0.637671  0.873746
# 32          0.629823  0.795338
# 33          0.515402  0.629534
# 34          0.562094  0.726727
# 35          0.507059  0.645821
# 36          0.433549  0.587290
# 37          0.560123  0.728227
# 38          0.581346  0.766459
# 39          0.619036  0.806020
# 40          0.617608  0.801383
# 41          0.588098  0.856087
# 42          0.615366  0.888741
# 43          0.662819  0.909686
# 44          0.592936  0.766457
# 45          0.644444  0.854527
# 46          0.709348  0.895406
# 47          0.659157  0.860133
# 48          0.629721  0.800116
# 49          0.497697  0.724341

# %% [markdown]
# ## Ward by Ward Participation 2006-2020

# %%
judicial_list = ['/Users/amy/Code/injustice_watch/Judicial General Data/judicial_general_2006.xlsx',
                '/Users/amy/Code/injustice_watch/Judicial General Data/judicial_general_2008.xlsx',
                '/Users/amy/Code/injustice_watch/Judicial General Data/judicial_general_2010.xlsx',
                '/Users/amy/Code/injustice_watch/Judicial General Data/judicial_general_2012.xlsx',
                '/Users/amy/Code/injustice_watch/Judicial General Data/judicial_general_2014.xlsx',
                '/Users/amy/Code/injustice_watch/Judicial General Data/judicial_general_2016.xlsx',
                '/Users/amy/Code/injustice_watch/Judicial General Data/judicial_general_2018.xlsx',
                '/Users/amy/Code/injustice_watch/Judicial General Data/judicial_general_2020.xlsx']

# %%
all_df_dict = {}
years_list = ['2006','2008','2010','2012','2014','2016','2018','2020']
ballot_measures_df = excel_to_df('/Users/amy/Code/injustice_watch/Judicial General Data/ballot_measures.xlsx')

index = 0

for pathname in judicial_list:
    print(index)
    df = excel_to_df(pathname)
    df = tag_retention(df)
    clean_df = df[df['Retention'] == 'Retention']
    clean_df = clean_df[~clean_df.RACE.isin(ballot_measures_df.RACE)]
    
    #group by race and ward
    grouped = clean_df.groupby(['WARD','RACE'], as_index=False).agg({'WARD': 'first','REGISTERED VOTERS': 'first',
                                                     'BALLOTS CAST': 'first','VOTES': 'sum'}).sort_values('VOTES',ascending=False)
    
    #find max votes in each ward
    grouped['max_votes'] = grouped.groupby(['WARD'])['VOTES'].transform(max)
    
    #consolidate by ward
    data_by_ward = grouped.groupby(['WARD'], as_index=False).agg({'WARD': 'first','REGISTERED VOTERS': 'first',
                                                     'BALLOTS CAST': 'first','max_votes':'first'})
    
    #make calculations
    data_by_ward['participation'] = data_by_ward['max_votes']/data_by_ward['BALLOTS CAST']
    data_by_ward['judicial turnout'] = data_by_ward['max_votes']/data_by_ward['REGISTERED VOTERS']
    data_by_ward['turnout'] = data_by_ward['BALLOTS CAST']/data_by_ward['REGISTERED VOTERS']

    #Add this year's dataframe to the dictionary with the year as the key
    current_year = years_list[index]
    print(current_year)
    all_df_dict[current_year] = data_by_ward
    
    index+=1
# Out:
# 0
# 2006
# 1
# 2008
# 2
# 2010
# 3
# 2012
# 4
# 2014
# 5
# 2016
# 6
# 2018
# 7
# 2020

# %%
#Inspect to make sure it matches with 2020
all_df_dict['2020']
# Out:
#     WARD  REGISTERED VOTERS  BALLOTS CAST  max_votes  participation  \
# 0    1.0            38017.0       30731.0    22563.0       0.734210
# 1    2.0            40366.0       34147.0    24038.0       0.703956
# 14          0.429478  0.542346
# 15          0.427305  0.548242
# 16          0.463150  0.603210
# 17          0.570199  0.685432
# 18          0.667605  0.831264
# 19          0.489349  0.639684
# 20          0.519139  0.664026
# 21          0.475212  0.588430
# 22          0.564610  0.696227
# 23          0.445344  0.600397
# 24          0.536528  0.724917
# 25          0.531825  0.696580
# 26          0.511661  0.722746
# 27          0.453585  0.613436
# 28          0.505341  0.659546
# 29          0.529365  0.683018
# 30          0.511900  0.647827
# 31          0.637671  0.873746
# 32          0.629823  0.795338
# 33          0.515402  0.629534
# 34          0.562094  0.726727
# 35          0.507059  0.645821
# 36          0.433549  0.587290
# 37          0.560123  0.728227
# 38          0.581346  0.766459
# 39          0.619036  0.806020
# 40          0.617608  0.801383
# 41          0.588098  0.856087
# 42          0.615366  0.888741
# 43          0.662819  0.909686
# 44          0.592936  0.766457
# 45          0.644444  0.854527
# 46          0.709348  0.895406
# 47          0.659157  0.860133
# 48          0.629721  0.800116
# 49          0.497697  0.724341

# %%
all_df_dict['2006'].head()
# Out:
#    WARD  REGISTERED VOTERS  BALLOTS CAST  max_votes  participation  \
# 0   1.0            27903.0       11412.0     6606.0       0.578864
# 1   2.0            31729.0       15202.0     9678.0       0.636627
# 2   3.0            22733.0       10294.0     6185.0       0.600835
# 3   4.0            27868.0       15682.0    10652.0       0.679250
# 4   5.0            28691.0       15011.0     9966.0       0.663913
#
#    judicial turnout   turnout
# 0          0.236749  0.408988
# 1          0.305021  0.479120
# 2          0.272071  0.452822
# 3          0.382231  0.562724
# 4          0.347356  0.523195

# %%
all_df_dict['2006'].tail()
# Out:
#     WARD  REGISTERED VOTERS  BALLOTS CAST  max_votes  participation  \
# 45  46.0            28030.0       14932.0     8824.0       0.590946
# 46  47.0            27041.0       17224.0    11338.0       0.658268
# 47  48.0            27138.0       15499.0     9522.0       0.614362
# 48  49.0            20322.0       10701.0     6968.0       0.651154
# 49  50.0            23995.0       11959.0     7196.0       0.601723
#
#     judicial turnout   turnout
# 45          0.314806  0.532715
# 46          0.419289  0.636959
# 47          0.350873  0.571118
# 48          0.342880  0.526572
# 49          0.299896  0.498395

# %%
#will need to loop through the dictionary and expeort as csv each dataframe value paired with the year key

# %% [markdown]
# # 2018 Primary

# %% [markdown]
# Run the same citywide and by ward participation calculations but for the primaires, which don't include retention races. Only included contested races, where there is more than one candidate, and exclude subcircuit races so only include countywide races.
#
# Democratice primary only?
#
# https://stackoverflow.com/questions/45752601/how-to-do-a-conditional-count-after-groupby-on-a-pandas-dataframe

# %%
#load data into pandas
df = pd.read_csv('../Judicial General Data/Dem Primaries/judicial_democratic_primary_2018.csv')

# %%
#inspect
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1922 entries, 0 to 1921
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   WARD               1922 non-null   int64
#  1   REGISTERED VOTERS  1922 non-null   int64
#  2   BALLOTS CAST       1922 non-null   int64
#  3   RACE               1922 non-null   object
#  4   CANDIDATE          1922 non-null   object
#  5   VOTES              1922 non-null   int64
# dtypes: int64(4), object(2)
# memory usage: 90.2+ KB

# %%
#remove subcircuits
df = tag_subcircuit(df)
df = df.loc[df['Subcircuit'] != 'Subcircuit']

# %%
#check if all subcircuits were removed. number of rows should be 1300
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1300 entries, 8 to 1921
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   WARD               1300 non-null   int64
#  1   REGISTERED VOTERS  1300 non-null   int64
#  2   BALLOTS CAST       1300 non-null   int64
#  3   RACE               1300 non-null   object
#  4   CANDIDATE          1300 non-null   object
#  5   VOTES              1300 non-null   int64
#  6   Subcircuit         1300 non-null   object
# dtypes: int64(4), object(3)
# memory usage: 81.2+ KB

# %%
#Look at just one ward
#Vacancy of Egan and Dunford are the only uncontested
df[df.WARD == 1]
# Out:
#     WARD  REGISTERED VOTERS  BALLOTS CAST  \
# 8      1              33159         10237
# 9      1              33159         10237
# 10     1              33159         10237
# 11     1              33159         10237
# 12     1              33159         10237
# 13     1              33159         10237
# 14     1              33159         10237
# 15     1              33159         10237
# 16     1              33159         10237
# 17     1              33159         10237
# 18     1              33159         10237
# 19     1              33159         10237
# 20     1              33159         10237
# 21     1              33159         10237
# 22     1              33159         10237
# 23     1              33159         10237
# 24     1              33159         10237
# 25     1              33159         10237
# 26     1              33159         10237
# 27     1              33159         10237
# 28     1              33159         10237
# 29     1              33159         10237
# 30     1              33159         10237
# 31     1              33159         10237
# 32     1              33159         10237
# 33     1              33159         10237
#
#                                                 RACE  \
# 8   Judge, Cook County Circuit (Vac. of Prendergast)
# 9   Judge, Cook County Circuit (Vac. of Prendergast)
# 10    Judge, Cook County Circuit (Vacancy of Brewer)
# 11    Judge, Cook County Circuit (Vacancy of Brewer)
# 12    Judge, Cook County Circuit (Vacancy of Brewer)
# 13      Judge, Cook County Circuit (Vacancy of Clay)
# 14      Judge, Cook County Circuit (Vacancy of Clay)
# 15      Judge, Cook County Circuit (Vacancy of Clay)
# 16      Judge, Cook County Circuit (Vacancy of Clay)
# 17   Judge, Cook County Circuit (Vacancy of Dooling)
# 18   Judge, Cook County Circuit (Vacancy of Dooling)
# 19   Judge, Cook County Circuit (Vacancy of Dooling)
# 20   Judge, Cook County Circuit (Vacancy of Dunford)
# 21      Judge, Cook County Circuit (Vacancy of Egan)
# 22  Judge, Cook County Circuit (Vacancy of Flanagan)
# 23  Judge, Cook County Circuit (Vacancy of Flanagan)
# 24  Judge, Cook County Circuit (Vacancy of Flanagan)
# 25  Judge, Cook County Circuit (Vacancy of Flanagan)
# 26  Judge, Cook County Circuit (Vacancy of Hartigan)
# 27  Judge, Cook County Circuit (Vacancy of Hartigan)
# 28    Judge, Cook County Circuit (Vacancy of Jordan)
# 29    Judge, Cook County Circuit (Vacancy of Jordan)
# 30    Judge, Cook County Circuit (Vacancy of Jordan)
# 31  Judge, Cook County Circuit (Vacancy of McGinnis)
# 32  Judge, Cook County Circuit (Vacancy of McGinnis)
# 33  Judge, Cook County Circuit (Vacancy of McGinnis)
#
#                     CANDIDATE  VOTES      Subcircuit
# 8                Jack Hagerty   4464  Not Subcircuit
# 9                Mable Taylor   2817  Not Subcircuit
# 10                 John Maher   1009  Not Subcircuit
# 11      Kathryn Maloney Vahey   4139  Not Subcircuit
# 12            Oran F. Whiting   2569  Not Subcircuit
# 13       Jonathan Clark Green   1259  Not Subcircuit
# 14  Kathaleen Theresa Lanahan   3902  Not Subcircuit
# 15             Lori Ann Roper   1338  Not Subcircuit
# 16        Michael I. O'Malley   1066  Not Subcircuit
# 17         Corri Diane Fetman   2337  Not Subcircuit
# 18       Timothy John Leeming   2728  Not Subcircuit
# 19             Tom Sam Sianis   2354  Not Subcircuit
# 20          Thomas F. McGuire   6376  Not Subcircuit
# 21           Rosa Maria Silva   7163  Not Subcircuit
# 22     Amanda Moira Pillsbury   1779  Not Subcircuit
# 23             Ioana Salajanu   1127  Not Subcircuit
# 24    Keely Patricia Hillison    835  Not Subcircuit
# 25          Preston Jones Jr.   3762  Not Subcircuit
# 26         Cecilia Anne Horan   6666  Not Subcircuit
# 27            Keith L. Spence    751  Not Subcircuit
# 28          Clare Joyce Quish   4989  Not Subcircuit
# 29              Jerry Barrido   1961  Not Subcircuit
# 30        Patrick Dankwa John    492  Not Subcircuit
# 31      Bradley R. Trowbridge   2087  Not Subcircuit
# 32      Brian Terrence Sexton   1362  Not Subcircuit
# 33     Peter Michael Gonzalez   3892  Not Subcircuit

# %%
#count the number of times a race apperas by ward 
contested_counts = df.groupby(['WARD','RACE'],as_index=False).count()

# %%
contested_counts.head()
# Out:
#    WARD                                              RACE  REGISTERED VOTERS  \
# 0     1  Judge, Cook County Circuit (Vac. of Prendergast)                  2
# 1     1    Judge, Cook County Circuit (Vacancy of Brewer)                  3
# 2     1      Judge, Cook County Circuit (Vacancy of Clay)                  4
# 3     1   Judge, Cook County Circuit (Vacancy of Dooling)                  3
# 4     1   Judge, Cook County Circuit (Vacancy of Dunford)                  1
#
#    BALLOTS CAST  CANDIDATE  VOTES  Subcircuit
# 0             2          2      2           2
# 1             3          3      3           3
# 2             4          4      4           4
# 3             3          3      3           3
# 4             1          1      1           1

# %%
#find the rows where CANDIDATE count = 1
uncontested = contested_counts.loc[contested_counts['CANDIDATE'] == 1]
uncontested
# Out:
#      WARD                                             RACE  REGISTERED VOTERS  \
# 4       1  Judge, Cook County Circuit (Vacancy of Dunford)                  1
# 5       1     Judge, Cook County Circuit (Vacancy of Egan)                  1
# 14      2  Judge, Cook County Circuit (Vacancy of Dunford)                  1
# 15      2     Judge, Cook County Circuit (Vacancy of Egan)                  1
# 24      3  Judge, Cook County Circuit (Vacancy of Dunford)                  1
# ..    ...                                              ...                ...
# 475    48     Judge, Cook County Circuit (Vacancy of Egan)                  1
# 484    49  Judge, Cook County Circuit (Vacancy of Dunford)                  1
# 485    49     Judge, Cook County Circuit (Vacancy of Egan)                  1
# 494    50  Judge, Cook County Circuit (Vacancy of Dunford)                  1
# 495    50     Judge, Cook County Circuit (Vacancy of Egan)                  1
#
#      BALLOTS CAST  CANDIDATE  VOTES  Subcircuit
# 4               1          1      1           1
# 5               1          1      1           1
# 14              1          1      1           1
# 15              1          1      1           1
# 24              1          1      1           1
# ..            ...        ...    ...         ...
# 475             1          1      1           1
# 484             1          1      1           1
# 485             1          1      1           1
# 494             1          1      1           1
# 495             1          1      1           1
#
# [100 rows x 7 columns]

# %%
#remove rows in df based on rows in uncontested
#based on this: https://stackoverflow.com/questions/39880627/in-pandas-how-to-delete-rows-from-a-data-frame-based-on-another-data-frame

df = df[~df.RACE.isin(uncontested.RACE)]
#should equal 1300-100 = 1200
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1200 entries, 8 to 1921
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   WARD               1200 non-null   int64
#  1   REGISTERED VOTERS  1200 non-null   int64
#  2   BALLOTS CAST       1200 non-null   int64
#  3   RACE               1200 non-null   object
#  4   CANDIDATE          1200 non-null   object
#  5   VOTES              1200 non-null   int64
#  6   Subcircuit         1200 non-null   object
# dtypes: int64(4), object(3)
# memory usage: 75.0+ KB

# %%
df.head()
# Out:
#     WARD  REGISTERED VOTERS  BALLOTS CAST  \
# 8      1              33159         10237
# 9      1              33159         10237
# 10     1              33159         10237
# 11     1              33159         10237
# 12     1              33159         10237
#
#                                                 RACE              CANDIDATE  \
# 8   Judge, Cook County Circuit (Vac. of Prendergast)           Jack Hagerty
# 9   Judge, Cook County Circuit (Vac. of Prendergast)           Mable Taylor
# 10    Judge, Cook County Circuit (Vacancy of Brewer)             John Maher
# 11    Judge, Cook County Circuit (Vacancy of Brewer)  Kathryn Maloney Vahey
# 12    Judge, Cook County Circuit (Vacancy of Brewer)        Oran F. Whiting
#
#     VOTES      Subcircuit
# 8    4464  Not Subcircuit
# 9    2817  Not Subcircuit
# 10   1009  Not Subcircuit
# 11   4139  Not Subcircuit
# 12   2569  Not Subcircuit

# %%
#find max votes for citywide
by_race = df.groupby('RACE').sum().sort_values('VOTES',ascending=False)
by_race.head(10)
# Out:
#                                                   WARD  REGISTERED VOTERS  \
# RACE
# Judge, Cook County Circuit (Vacancy of Brewer)    3825            4482597
# Judge, Cook County Circuit (Vacancy of Clay)      5100            5976796
# Judge, Cook County Circuit (Vacancy of Flanagan)  5100            5976796
# Judge, Cook County Circuit (Vacancy of Dooling)   3825            4482597
# Judge, Cook County Circuit (Vac. of Prendergast)  2550            2988398
# Judge, Cook County Circuit (Vacancy of Hartigan)  2550            2988398
# Judge, Cook County Circuit (Vacancy of Jordan)    3825            4482597
# Judge, Cook County Circuit (Vacancy of McGinnis)  3825            4482597
#
#                                                   BALLOTS CAST   VOTES
# RACE
# Judge, Cook County Circuit (Vacancy of Brewer)         1357587  358540
# Judge, Cook County Circuit (Vacancy of Clay)           1810116  356112
# Judge, Cook County Circuit (Vacancy of Flanagan)       1810116  348345
# Judge, Cook County Circuit (Vacancy of Dooling)        1357587  345126
# Judge, Cook County Circuit (Vac. of Prendergast)        905058  343713
# Judge, Cook County Circuit (Vacancy of Hartigan)        905058  343316
# Judge, Cook County Circuit (Vacancy of Jordan)         1357587  342348
# Judge, Cook County Circuit (Vacancy of McGinnis)       1357587  340666

# %%
max_votes = by_race['VOTES'].max()
print(max_votes)
# Out:
# 358540

# %% [markdown]
# # Primaries citywide 2006-2020

# %% [markdown]
# Don't need to tag retention races because there are no retention races in the primaries. Need to add back subcircuits. Did a check by printing out row numbers of clean_df and checking if for 2018 it equaled 1200 after cleaning and by checking to see if the max votes for 2018 = 358540

# %%
judicial_primary_list = ['/Users/amy/Code/injustice_watch/Judicial General Data/Dem Primaries/judicial_democratic_primary_2006.csv',
                '/Users/amy/Code/injustice_watch/Judicial General Data/Dem Primaries/judicial_democratic_primary_2008.csv',
                '/Users/amy/Code/injustice_watch/Judicial General Data/Dem Primaries/judicial_democratic_primary_2010.csv',
                '/Users/amy/Code/injustice_watch/Judicial General Data/Dem Primaries/judicial_democratic_primary_2012.csv',
                '/Users/amy/Code/injustice_watch/Judicial General Data/Dem Primaries/judicial_democratic_primary_2014.csv',
                '/Users/amy/Code/injustice_watch/Judicial General Data/Dem Primaries/judicial_democratic_primary_2016.csv',
                '/Users/amy/Code/injustice_watch/Judicial General Data/Dem Primaries/judicial_democratic_primary_2018.csv',
                '/Users/amy/Code/injustice_watch/Judicial General Data/Dem Primaries/judicial_democratic_primary_2020.csv']

# %%
primary_participation_list = []
primary_jud_turnout_list = []
primary_turnout_list = []
years_list = ['2006','2008','2010','2012','2014','2016','2018','2020']
ballot_measures_df = excel_to_df('/Users/amy/Code/injustice_watch/Judicial General Data/ballot_measures.xlsx')

index = 0

for pathname in judicial_primary_list:
    print(index)
    
    #load data
    df = pd.read_csv(pathname)
    #df = tag_retention(df) No retention in primaries
    
    #clean data
    #clean_df = df[df['Retention'] == 'Retention']
    #clean_df = clean_df[~clean_df.RACE.isin(ballot_measures_df.RACE)]
    df = tag_subcircuit(df)
    clean_df = df.loc[df['Subcircuit'] != 'Subcircuit']
    
    #take out uncontested races
    contested_counts = clean_df.groupby(['WARD','RACE'],as_index=False).count()
    uncontested = contested_counts.loc[contested_counts['CANDIDATE'] == 1]
    clean_df = clean_df[~clean_df.RACE.isin(uncontested.RACE)]
    
    #print(clean_df.info())
    
    #find race w most votes
    by_race = clean_df.groupby('RACE').sum().sort_values('VOTES',ascending=False)
    print(by_race.head(3))
    max_votes = by_race['VOTES'].max()
    print('max votes')
    print(max_votes)
    
    #find denominators
    by_ward = clean_df.groupby('WARD').agg({'REGISTERED VOTERS':'first','BALLOTS CAST':'first'})
    registered = by_ward['REGISTERED VOTERS'].sum()
    ballots = by_ward['BALLOTS CAST'].sum()
    print('ballots')
    print(ballots)
    
    #participation
    participation = max_votes/ballots
    primary_participation_list.append(participation)
    
    #judicial_turnout
    judicial_turnout = max_votes/registered
    primary_jud_turnout_list.append(judicial_turnout)
    
    #voter turnout
    turnout = ballots/registered
    primary_turnout_list.append(turnout)
    
    index+=1
# Out:
# 0
#                                              WARD  REGISTERED VOTERS  \
# RACE
# Circuit Court Judge (Vac. Burr)              5100            5195488
# APELLATE COURT JUDGE 1ST DIST(VAC.HARTIGAN)  6375            6494360
# APELLATE COURT JUDGE 1ST DIST(VAC. HARTMAN)  6375            6494360
#
#                                              BALLOTS CAST   VOTES
# RACE
# Circuit Court Judge (Vac. Burr)                   1563564  313549
# APELLATE COURT JUDGE 1ST DIST(VAC.HARTIGAN)       1954455  311283
# APELLATE COURT JUDGE 1ST DIST(VAC. HARTMAN)       1954455  308285
# max votes
# 313549
# ballots
# 390891
# 1
#                                                     WARD  REGISTERED VOTERS  \
# RACE
# Judge of the Appellate Court (Vacancy of Burke)     3825            3922557
# Appellate Court Judge (Vacancy of Neville, Jr.)  5100            6098392
# Appellate Court Judge (Vacancy of Simon)         2550            3049196
#
#                                                  BALLOTS CAST   VOTES
# RACE
# Supreme Court Judge (Vacancy of Freeman)              3880947  469492
# Appellate Court Judge (Vacancy of Neville, Jr.)       2217684  441387
# Appellate Court Judge (Vacancy of Simon)              1108842  428129
# max votes
# 469492
# ballots
# 554421

# %%
primary_participation_list
# Out:
# [0.8021392152799629,
#  0.7685866436429432,
#  0.8135796498153465,
#  0.9019957247838994,
#  0.852646708689236,
#  0.6955156129476202,
#  0.7923028137423237,
#  0.8468149655225903]

# %%
#save into a dictionary and convert to df
dict_to_df = {
    'Year':years_list,
    'Participation':primary_participation_list,
    'Judicial Turnout':primary_jud_turnout_list,
    'Voter Turnout':primary_turnout_list,
}

primary_summary_df = pd.DataFrame(dict_to_df)
primary_summary_df
# Out:
#    Year  Participation  Judicial Turnout  Voter Turnout
# 0  2006       0.802139          0.241401       0.300947
# 1  2008       0.768587          0.377179       0.490744
# 2  2010       0.813580          0.201495       0.247665
# 3  2012       0.901996          0.187024       0.207345
# 4  2014       0.852647          0.113589       0.133220
# 5  2016       0.695516          0.330934       0.475811
# 6  2018       0.792303          0.239955       0.302857
# 7  2020       0.846815          0.307945       0.363651

# %% [markdown]
# ## Ward by Ward Democratic Primary 2006-2020

# %%
judicial_primary_list = ['/Users/amy/Code/injustice_watch/Judicial General Data/Dem Primaries/judicial_democratic_primary_2006.csv',
                '/Users/amy/Code/injustice_watch/Judicial General Data/Dem Primaries/judicial_democratic_primary_2008.csv',
                '/Users/amy/Code/injustice_watch/Judicial General Data/Dem Primaries/judicial_democratic_primary_2010.csv',
                '/Users/amy/Code/injustice_watch/Judicial General Data/Dem Primaries/judicial_democratic_primary_2012.csv',
                '/Users/amy/Code/injustice_watch/Judicial General Data/Dem Primaries/judicial_democratic_primary_2014.csv',
                '/Users/amy/Code/injustice_watch/Judicial General Data/Dem Primaries/judicial_democratic_primary_2016.csv',
                '/Users/amy/Code/injustice_watch/Judicial General Data/Dem Primaries/judicial_democratic_primary_2018.csv',
                '/Users/amy/Code/injustice_watch/Judicial General Data/Dem Primaries/judicial_democratic_primary_2020.csv']

# %%
all_primary_df_dict = {}
years_list = ['2006','2008','2010','2012','2014','2016','2018','2020']
ballot_measures_df = excel_to_df('/Users/amy/Code/injustice_watch/Judicial General Data/ballot_measures.xlsx')

index = 0

for pathname in judicial_primary_list:
    #load data
    df = pd.read_csv(pathname)
    
    #take out subcircuits
    df = tag_subcircuit(df)
    clean_df = df.loc[df['Subcircuit'] != 'Subcircuit']
    
    #take out uncontested races
    contested_counts = clean_df.groupby(['WARD','RACE'],as_index=False).count()
    uncontested = contested_counts.loc[contested_counts['CANDIDATE'] == 1]
    clean_df = clean_df[~clean_df.RACE.isin(uncontested.RACE)]
    
    #group by race and ward
    grouped = clean_df.groupby(['WARD','RACE'], as_index=False).agg({'WARD': 'first','REGISTERED VOTERS': 'first',
                                                     'BALLOTS CAST': 'first','VOTES': 'sum'}).sort_values('VOTES',ascending=False)
    
    #find max votes in each ward
    grouped['max_votes'] = grouped.groupby(['WARD'])['VOTES'].transform(max)
    
    print(grouped.head())
    
    #consolidate by ward
    data_by_ward = grouped.groupby(['WARD'], as_index=False).agg({'WARD': 'first','REGISTERED VOTERS': 'first',
                                                     'BALLOTS CAST': 'first','max_votes':'first'})
    
    #make calculations
    data_by_ward['participation'] = data_by_ward['max_votes']/data_by_ward['BALLOTS CAST']
    data_by_ward['judicial turnout'] = data_by_ward['max_votes']/data_by_ward['REGISTERED VOTERS']
    data_by_ward['turnout'] = data_by_ward['BALLOTS CAST']/data_by_ward['REGISTERED VOTERS']

    #Add this year's dataframe to the dictionary with the year as the key
    current_year = years_list[index]
    print(current_year)
    all_primary_df_dict[current_year] = data_by_ward
    
    index+=1
# Out:
#                                             RACE  WARD  REGISTERED VOTERS  \
# 127  APELLATE COURT JUDGE 1ST DIST(VAC.HARTIGAN)    19              36708
# 128              Circuit Court Judge (Vac. Burr)    19              36708
# 129             Circuit Court Judge (Vac. Jaffe)    19              36708
# 131          Circuit Court Judge (Vac. Schiller)    19              36708
# 126  APELLATE COURT JUDGE 1ST DIST(VAC. HARTMAN)    19              36708
#
#      BALLOTS CAST  VOTES  max_votes
# 127         16615  14330      14330
# 128         16615  14167      14330
# 129         16615  14164      14330
# 131         16615  14164      14330
# 126         16615  13845      14330
# 2006
#                                                   RACE  WARD  \
# 220    Judge of the Appellate Court (Vacancy of Burke)    21
# 78   Judge of the Appellate Court (Vacancy of Campb...     8
# 221  Judge of the Appellate Court (Vacancy of Campb...    21
# 77     Judge of the Appellate Court (Vacancy of Burke)     8
# 56   Judge of the Appellate Court (Vacancy of Campb...     6
#
#      REGISTERED VOTERS  BALLOTS CAST  VOTES  max_votes
# 220              38383         21904  18242      18242
# 78               35805         21229  18073      18073
# 221              38383         21904  18026      18242
# 77               35805         21229  17741      18073
# 56               34854         19998  17431      17431
# 2008
#                                             RACE  WARD  REGISTERED VOTERS  \
# 163  Appellate Court Judge (Vacancy of O'Malley)    19              32355
# 162   Appellate Court Judge (Vacancy of McNulty)    19              32355
# 167       Circuit Court Judge (Vacancy of Dolan)    19              32355
# 164     Appellate Court Judge (Vacancy of South)    19              32355
# 170       Circuit Court Judge (Vacancy of Riley)    19              32355
#
#      BALLOTS CAST  VOTES  max_votes
# 163         16098  14173      14173
# 162         16098  13783      14173
# 167         16098  13522      14173
# 164         16098  13058      14173
# 170         16098  13011      14173
# 2010
#                                                 RACE  WARD  REGISTERED VOTERS  \
# 227      Supreme Court Judge (Vacancy of Fitzgerald)    19              32312
# 216        Appellate Court Judge (Vacancy of Cahill)    19              32312
# 217     Appellate Court Judge (Vacancy of Gallagher)    19              32312
# 220  Circuit Court Judge (Vacancy of Kirie Kinnaird)    19              32312
# 218       Appellate Court Judge (Vacancy of O'Brien)    19              32312
#
#      BALLOTS CAST  VOTES  max_votes
# 227         11800  10911      10911
# 216         11800  10022      10911
# 217         11800   9977      10911
# 220         11800   9698      10911
# 218         11800   9643      10911
# 2012
#                                               RACE  WARD  REGISTERED VOTERS  \
# 56           Appellate Court Judge (Vac of Gordon)     8              36168
# 144          Appellate Court Judge (Vac of Gordon)    19              33907
# 57           Appellate Court Judge (Vac of Steele)     8              36168
# 60   Judge, Cook County Circuit (Vac of Hill Veal)     8              36168
# 58      Judge, Cook County Circuit (Vac of Arnold)     8              36168
#
#      BALLOTS CAST  VOTES  max_votes
# 56           7290   6701       6701
# 144          7335   6273       6273
# 57           7290   6255       6701
# 60           7290   6218       6701
# 58           7290   6201       6701
# 2014
#                                          RACE  WARD  REGISTERED VOTERS  \
# 57     Circuit Court Judge (Vacancy of Hogan)     8              38421
# 59   Circuit Court Judge (Vacancy of Johnson)     8              38421
# 60  Circuit Court Judge (Vacancy of Karnezis)     8              38421
# 63     Circuit Court Judge (Vacancy of Walsh)     8              38421
# 61    Circuit Court Judge (Vacancy of Palmer)     8              38421
#
#     BALLOTS CAST  VOTES  max_votes
# 57         20851  15866      15866
# 59         20851  15774      15866
# 60         20851  15750      15866
# 63         20851  15696      15866
# 61         20851  15680      15866
# 2016
#                                                  RACE  WARD  \
# 146      Judge, Cook County Circuit (Vacancy of Clay)    19
# 145    Judge, Cook County Circuit (Vacancy of Brewer)    19
# 144  Judge, Cook County Circuit (Vac. of Prendergast)    19
# 151  Judge, Cook County Circuit (Vacancy of McGinnis)    19
# 147   Judge, Cook County Circuit (Vacancy of Dooling)    19
#
#      REGISTERED VOTERS  BALLOTS CAST  VOTES  max_votes
# 146              36508         15911  12926      12926
# 145              36508         15911  12735      12926
# 144              36508         15911  12415      12926
# 151              36508         15911  12383      12926
# 147              36508         15911  12106      12926
# 2018
#                                                 RACE  WARD  REGISTERED VOTERS  \
# 704         Supreme Court Judge (Vacancy of Freeman)    47              38574
# 284         Supreme Court Judge (Vacancy of Freeman)    19              36684
# 690  Appellate Court Judge (Vacancy of Neville, Jr.)    47              38574
# 691         Appellate Court Judge (Vacancy of Simon)    47              38574
# 274         Circuit Court Judge (Vacancy of Coghlan)    19              36684
#
#      BALLOTS CAST  VOTES  max_votes
# 704         19690  16159      16159
# 284         18118  15712      15712
# 690         19690  15523      16159
# 691         19690  15130      16159
# 274         18118  14734      15712
# 2020

# %%
#test
test = all_primary_df_dict['2020']
test.head()
# Out:
#    WARD  REGISTERED VOTERS  BALLOTS CAST  max_votes  participation  \
# 0     1              35398         14211      11343       0.798185
# 1     2              38016         14025      10733       0.765276
# 2     3              36810         14058      11893       0.845995
# 3     4              34091         15502      13488       0.870081
# 4     5              29415         13766      12047       0.875127
#
#    judicial turnout   turnout
# 0          0.320442  0.401463
# 1          0.282328  0.368924
# 2          0.323092  0.381907
# 3          0.395647  0.454724
# 4          0.409553  0.467993

# %% [markdown]
# ## Export ward by ward data as CSV

# %% [markdown]
# Export 2006-2020 data stored in all_df_dict and all_primary_df_dict

# %%
for key,value in all_df_dict.items():
    pathname = '/Users/amy/Code/injustice_watch/analysis/general_v3_' + key + '.csv'
    value.to_csv(pathname)

# %%
for key,value in all_primary_df_dict.items():
    pathname = '/Users/amy/Code/injustice_watch/analysis/dprimary_v3_' + key + '.csv'
    value.to_csv(pathname)

# %%
#Will do this at the very end
